# %% [markdown]
# Carregamento de daddos

# %%
import pandas as pd
import matplotlib.pyplot as plt

br_df = pd.read_csv('ResultadoBrasileirao.csv')
br_df.head(5)
# Out:
#   Cell In[107], line 5
#     br_df.[['fase'] == '3ª fase']
#           ^
# SyntaxError: invalid syntax
